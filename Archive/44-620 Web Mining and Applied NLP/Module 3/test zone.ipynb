# %%
# Module Imports
import random as rng
from matplotlib import pyplot as plt
from matplotlib import style
from collections import Counter
import numpy as np

sizes = [10, 20, 50, 100, 1000, 5000]
insertion_sort_times = [0.0010252999999999998, 0.0027026999999999954, 0.010147200000000002, 0.0381137, 3.6303399, 91.2180796]
merge_sort_times = [0.00161889999999687, 0.003635600000009731, 0.0090655000000055, 0.020108000000007564, 0.2687474000000094, 1.6147050999999948]

# %%
plt.xticks(insertion_sort_times, sizes, label='merg')
plt.xticks(merge_sort_times, sizes, label='insert')

plt.xlabel("X Axis")
plt.ylabel("Y Axis")

plt.xticks(ticks=None, labels=None)

plt.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# Python program to set x-axis values in matplotlib
 
import matplotlib.pyplot as plt
 
# x-axis and y-axis values for plotting
x = [1, 20, 30, 4000,4500, 5000]
y = [30, 100, 4000, 500, 300, 60]
 
 
# Plotting x-axis and y-axis
plt.plot(x, y)
 
# naming of x-axis and y-axis
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
 
# naming the title of the plot
plt.title("Set X-Axis Values in Matplotlib")
 
# setting x-axis values
plt.xticks(x, sizes)
 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [73], line 21
#      18 plt.title("Set X-Axis Values in Matplotlib")
#      20 # setting x-axis values
# ---> 21 plt.xticks(x, sizes)
#      23 plt.show()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\pyplot.py:1824, in xticks(ticks, labels, minor, **kwargs)
#    1822         l._internal_update(kwargs)
#    1823 else:
# -> 1824     labels = ax.set_xticklabels(labels, minor=minor, **kwargs)
#    1826 return locs, labels
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\axes\_base.py:73, in _axis_method_wrapper.__set_name__.<locals>.wrapper(self, *args, **kwargs)
#      72 def wrapper(self, *args, **kwargs):
# ---> 73     return get_method(self)(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\axis.py:1968, in Axis._set_ticklabels(self, labels, fontdict, minor, **kwargs)
#    1966 if fontdict is not None:
#    1967     kwargs.update(fontdict)
# -> 1968 return self.set_ticklabels(labels, minor=minor, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\axis.py:1890, in Axis.set_ticklabels(self, ticklabels, minor, **kwargs)
#    1886 if isinstance(locator, mticker.FixedLocator):
#    1887     # Passing [] as a list of ticklabels is often used as a way to
#    1888     # remove all tick labels, so only error for > 0 ticklabels
#    1889     if len(locator.locs) != len(ticklabels) and len(ticklabels) != 0:
# -> 1890         raise ValueError(
#    1891             "The number of FixedLocator locations"
#    1892             f" ({len(locator.locs)}), usually from a call to"
#    1893             " set_ticks, does not match"
#    1894             f" the number of ticklabels ({len(ticklabels)}).")
#    1895     tickd = {loc: lab for loc, lab in zip(locator.locs, ticklabels)}
#    1896     func = functools.partial(self._format_with_dict, tickd)
#
# ValueError: The number of FixedLocator locations (6), usually from a call to set_ticks, does not match the number of ticklabels (10).

# %%
# Module Imports
import random as rng
from matplotlib import pyplot as plt
from matplotlib import style
from collections import Counter
import numpy as np

sizes = [10, 20, 50, 100, 1000, 5000]
insertion_sort_times = [0.0010252999999999998, 0.0027026999999999954, 0.010147200000000002, 0.0381137, 3.6303399, 91.2180796]
merge_sort_times = [0.00161889999999687, 0.003635600000009731, 0.0090655000000055, 0.020108000000007564, 0.2687474000000094, 1.6147050999999948]

plt.plot(sizes, insertion_sort_times, color='magenta')
plt.plot(sizes, merge_sort_times)
plt.title('Sort Time VS Merge Sort Time', fontsize=20)
plt.xlabel('Size', fontsize=14, labelpad=5)
plt.ylabel('Time', fontsize=14, labelpad=5)
plt.grid()
